# %%
import pandas as pd
from contractions import TextProcessor, TextProcessorConfig  # Correct import

# Load your data
df = pd.read_csv('/Users/notagain/data_preprocessing/so_many_rev.csv')

# 1. Initialize TextProcessor (with default config)
processor = TextProcessor(num_processes=4)  # Example with default settings

# 2. Apply text processing
processed_df = processor.process_text_for_comparison(df.copy(), text_column='text')

# 3. Generate Analysis Report
processor.generate_analysis_report(df, text_column="text", comparison_df=processed_df)

# 4. Analyze nouns
processor.analyze_nouns(processed_df, text_column='text', rating_column='rating')

# 5. Print most common words
processor.print_most_common_words(processed_df, text_column='text', top_n=30)

# 6. Print most common words by rating
processor.print_most_common_words_by_rating(processed_df, text_column='text', rating_column='rating', top_n=10)
# Out:
# Similarity Analysis:
#                                                     text  \
# 0      It's extremely pricey so I specifically asked ...
# 1      Wrong part ordered at first by the salesman.  ...
# 2      My order was canceled without explanation.  Re...
# 3      The review Cookflights.com  is connected with ...
# 4      Put $400 a month away into a bank account don'...
# ...                                                  ...
# 60870  Darmawan our driver was great. He even partici...
# 60871  The Notary was very patient and attentive.  Th...
# 60872  Rush hour traffic inhibited initial service bu...
# 60873  Green City Pros delivered exceptional AC repla...
# 60874  The salesperson’s understanding of what I was ...
#
#        original_vs_modified_similarity
# 0                                  1.0
# 1                                  1.0
# 2                                  1.0
# 3                                  1.0
# 4                                  1.0
# ...
